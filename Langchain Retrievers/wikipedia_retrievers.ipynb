# %%
# !pip install langchain langchain-community wikipedia
# Out:
# Requirement already satisfied: langchain in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (1.3.14)
# Requirement already satisfied: langchain-community in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (0.4.2)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain) (1.5.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (0.10.6)
# Requirement already satisfied: numpy>=1.26.2 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (2.5.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: beautifulsoup4 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from wikipedia) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: anyio>=3.5.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.4)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from beautifulsoup4->wikipedia) (2.9.1)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/ubuntu/Generative AI Using LangChain/venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11756 sha256=a915f5389246f4e54d6eb5a4833f567162a3460e2d24747165ad1a6a73f1f92f
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
retriever=WikipediaRetriever(top_k_results=2,lang="en")

# %%
query="What is pakistan?"

# %%
docs=retriever.invoke(query)

# %%
for i,doc in enumerate(docs):
    print(f"\n Result {i+1}")
    print(f"Content: {doc.page_content}")
# Out:
#  Result 1
# Content: Pakistan, officially the Islamic Republic of Pakistan, is a country in South Asia. It is the fifth-most populous country, with a population of over 241.5 million, having the second-largest Muslim population as of 2023. Islamabad is the nation's capital, while Karachi is its largest city and financial centre. Pakistan is the 33rd-largest country by area. Bounded by the Arabian Sea on the south, the Gulf of Oman on the southwest, and the Sir Creek on the southeast, it shares land borders with India to the east; Afghanistan to the west; Iran to the southwest; and China to the northeast. It shares a maritime border with Oman in the Gulf of Oman, and is separated from Tajikistan in the northwest by Afghanistan's narrow Wakhan Corridor.
# Pakistan is the site of several ancient cultures, including the 8,500-year-old Neolithic site of Mehrgarh in Balochistan, the Indus Valley Civilisation of the Bronze Age, and the ancient Gandhara civilisation. The regions that compose the modern state of Pakistan were the realm of multiple empires and dynasties, including the Achaemenid, the Maurya, the Kushan, the Gupta; the Umayyad Caliphate in its southern regions, the Hindu Shahis, the Ghaznavids, the Delhi Sultanate, the Samma, the Shah Miris, the Mughals, and finally, the British Raj from 1858 to 1947.
# Spurred by the Pakistan Movement, which sought a homeland for the Muslims of British India, and election victories in 1946 by the All-India Muslim League, Pakistan gained independence in 1947 after the partition of British India, which awarded separate statehood to its Muslim-majority regions and was accompanied by an unparalleled mass migration and loss of life. Initially a dominion of the British Commonwealth, Pakistan adopted a republican constitution in 1956 and became an Islamic republic with two geographically separate provinces, East Pakistan and West Pakistan. East Pakistan seceded as the new country of Bangladesh in 1971 after a nine-month-long civil war. In the following four decades, Pakistan has been ruled by governments that alternated between civilian and military, democratic and authoritarian, relatively secular and Islamist.
# Pakistan is considered a middle power and is a declared nuclear-weapon state, with the world's seventh-largest standing armed forces. The Pakistani economy is ranked amongst the world's emerging and growth-leading economies, with a large and rapidly growing middle class. Pakistan's political history since independence has been characterised by periods of significant economic and military growth as well as those of political and economic instability. It is an ethnically and linguistically diverse country, with similarly diverse geography and wildlife. The country continues to face poverty, illiteracy, corruption, and terrorism. Pakistan is a member of the United Nations, the Shanghai Cooperation Organisation, the Organisation of Islamic Cooperation, the Commonwealth of Nations, the South Asian Association for Regional Cooperation, and the Islamic Military Counter-Terrorism Coalition, and is designated as a major non-NATO ally by the United States.
